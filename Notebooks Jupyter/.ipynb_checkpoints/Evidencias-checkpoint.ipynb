# %% [markdown]
# # Evidencias
#
# #### Matias Celada

# %% [markdown]
# ### Semana 1

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Semana 2

# %% [markdown]
# Esta semana complete la tarea semanal 1. Tuve varias dificultades y algunos conceptos de TC1 que tengo flojos asique comence a leer el libro de Schauman desde el principio. Por ahora complete el Cap 1.
# Organize un poco el notebook y github para poder subir las entregas mas organizadas.

# %% [markdown]
# ### 27/04

# %% [markdown]
# - Lectura de Schauman. Caps 1, 2

# %% [markdown]
# ### 30/04

# %% [markdown]
# - Lectura Schauman Caps 3,4 y 5
# - Resumen del libro + circuitos por separado

# %% [markdown]
# ### 01/05

# %% [markdown]
# - Ejercicios + Resumen + Comienzo con la TS3

# %%
from IPython.display import IFrame
IFrame("./ejerciciosal0105.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./ejerciciosal0105.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - Falta corregir la TS2 y terminar con ejercicios

# %% [markdown]
# ### 07/05

# %% [markdown]
# - TS3

# %%
from IPython.display import IFrame
IFrame("./TS3_V2.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS3_V2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 08/05

# %% [markdown]
# - Videos Clase 4. Chebyshev.

# %%
from IPython.display import IFrame
IFrame("./Clase4-YT.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./Clase4-YT.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 26/05

# %% [markdown]
# - Estuve trabajando en la TS4. Esta subida en https://nbviewer.org/github/MCelada/TC2/blob/main/Notebooks%20Jupyter/TS4.ipynb

# %% [markdown]
# ### 29/05

# %% [markdown]
# - Simulacion en LTSpice TS4

# %% [markdown]
# ### 10/06

# %% [markdown]
# - Estudio teoria Funciones Bilineales y Bicuadraticas
# - Trabaje en la correccion de la TS2 y TS3. Mañana seran subidas

# %% [markdown]
# ### 11/06

# %% [markdown]
# - Practica Python y LTSpice
