# %% [markdown]
# # Tarea Semanal 2
#
# ##### Matias Celada

# %%
from IPython.display import IFrame
IFrame("./TS2_v2.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS2_v2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulacion en LTSpice

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
