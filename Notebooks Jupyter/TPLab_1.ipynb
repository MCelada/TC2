# %% [markdown]
# # Trabajo Práctico de Laboratorio 1: Teoría Moderna y Filtrado Activo

# %% [markdown]
# ## Autores
#     - Celada, Matias
#     - Gerez, Victor Rodolfo
#     - Moharos, David
#     - Niño, Jorge

# %% [markdown]
# ## Objetivos
#
#     - Consolidar los conceptos de teoría moderna mediante la implementación circuital.
#     - Simular e implementar el filtro con componentes activos de precisión.
#     - Medir las partes de la función transferencia para frecuencias menores a 100 kHz.

# %% [markdown]
# ## Descripción
#
#     - El trabajo práctico consiste en el diseño, análisis, medición y discusión de un filtro activo.

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
#     - Utilizaremos el UAF42, el cual contiene integrados capacitores de muy baja tolerancia, lo que permite obtener respuestas en frecuencia del filtro suimamente similares a las simulaciones.

# %% [markdown]
# ## Cálculos previos a las pruebas

# %% [markdown]
# ### Plantilla filtro pasa altos objetivo

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
import math

# %%
alfa_min = 20
alfa_max = 1
fs = 1200
fp = 4600

ws = 2 * math.pi * fs
wp = 2 * math.pi * fp
omega_w = wp
ws_norm = ws/omega_w
wp_norm = wp/omega_w

# %% [markdown]
# ### Plantilla filtro pasa altos objetivo

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
